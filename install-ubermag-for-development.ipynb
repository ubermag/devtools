# %% [markdown]
# ## Run this notebook to set up ubermag developer install

# %% [markdown]
# We assume we are in the directory of the `ubermag/devtools` repository.
#
# If not, this can be cloned from with

# %%
# !git clone git@github.com:ubermag/devtools.git ubermag-devtools

# %%
# !pwd
# Out:
# /Users/fangohr/git/ubermag-devtools

# %% [markdown]
# ## Create the right conda environment

# %%
# if you already have a "joommf-dev" environment, you may want to delete it using
# !conda remove -y -n joommf-dev --all

# %% [markdown]
# Create conda environment with dependencies we need, in particular OOMMF itself:

# %%
# !conda create -y -n ubermag-dev -c conda-forge numpy matplotlib pytest \
 pytest-cov sarge oommf ipython notebook
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev
#
#   added / updated specs:
#     - ipython
#     - matplotlib
#     - notebook
#     - numpy
#     - oommf
#     - pytest
#     - pytest-cov
#     - sarge
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appnope-0.1.2              |   py39h6e9494a_1          10 KB  conda-forge
#     argon2-cffi-20.1.0         |   py39hcbf5805_2          45 KB  conda-forge
#     attrs-21.2.0               |     pyhd8ed1ab_0          44 KB  conda-forge
#     backports.functools_lru_cache-1.6.4|     pyhd8ed1ab_0           9 KB  conda-forge
#     certifi-2020.12.5          |   py39h6e9494a_1         143 KB  conda-forge
#     cffi-1.14.5                |   py39h319c39b_0         219 KB  conda-forge
#     coverage-5.5               |   py39h89e85a6_0         257 KB  conda-forge
#     decorator-5.0.7            |     pyhd8ed1ab_0          11 KB  conda-forge
#     importlib-metadata-4.0.1   |   py39h6e9494a_0          30 KB  conda-forge
#     ipykernel-5.5.4            |   py39h71a6800_0         167 KB  conda-forge
#     ipython-7.23.1             |   py39h71a6800_0         1.1 MB  conda-forge
#     jedi-0.18.0                |   py39h6e9494a_2         932 KB  conda-forge
#     jupyter_core-4.7.1         |   py39h6e9494a_0          72 KB  conda-forge
#     kiwisolver-1.3.1           |   py39hedf5dff_1          59 KB  conda-forge
#     libblas-3.9.0              |       9_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |       9_openblas          11 KB  conda-forge
#     libffi-3.3                 |       h046ec9c_2          45 KB  conda-forge
#     libgfortran-5.0.0          |9_3_0_h6c81a4c_22          19 KB  conda-forge
#     libgfortran5-9.3.0         |      h6c81a4c_22         1.7 MB  conda-forge
#     liblapack-3.9.0            |       9_openblas          11 KB  conda-forge
#     libopenblas-0.3.15         |openmp_h5e1b9a4_0         8.7 MB  conda-forge
#     libtiff-4.2.0              |       h7c11950_1         623 KB  conda-forge
#     libwebp-base-1.2.0         |       h0d85af4_2         700 KB  conda-forge
#     llvm-openmp-11.1.0         |       hda6cdc1_1         268 KB  conda-forge
#     markupsafe-1.1.1           |   py39hcbf5805_3          25 KB  conda-forge
#     matplotlib-3.4.2           |   py39h6e9494a_0           7 KB  conda-forge
#     matplotlib-base-3.4.2      |   py39hb07454d_0         7.2 MB  conda-forge
#     matplotlib-inline-0.1.2    |     pyhd8ed1ab_2          11 KB  conda-forge
#     mistune-0.8.4              |py39hcbf5805_1003          54 KB  conda-forge
#     more-itertools-8.7.0       |     pyhd8ed1ab_1          39 KB  conda-forge
#     nbconvert-6.0.7            |   py39h6e9494a_3         530 KB  conda-forge
#     nbformat-5.1.3             |     pyhd8ed1ab_0          47 KB  conda-forge
#     nest-asyncio-1.5.1         |     pyhd8ed1ab_0           9 KB  conda-forge
#     notebook-6.3.0             |     pyha770c72_1         6.1 MB  conda-forge
#     numpy-1.20.2               |   py39h7eed0ac_0         5.4 MB  conda-forge
#     openjpeg-2.4.0             |       h6cbf5cd_0         446 KB  conda-forge
#     openssl-1.1.1k             |       h0d85af4_0         1.9 MB  conda-forge
#     pandoc-2.13                |       h0d85af4_0        13.2 MB  conda-forge
#     parso-0.8.2                |     pyhd8ed1ab_0          68 KB  conda-forge
#     pillow-8.1.2               |   py39h5fdd921_1         653 KB  conda-forge
#     pip-21.1.1                 |     pyhd8ed1ab_0         1.1 MB  conda-forge
#     pluggy-0.13.1              |   py39h6e9494a_4          29 KB  conda-forge
#     prometheus_client-0.10.1   |     pyhd8ed1ab_0          46 KB  conda-forge
#     prompt-toolkit-3.0.18      |     pyha770c72_0         244 KB  conda-forge
#     pygments-2.9.0             |     pyhd8ed1ab_0         754 KB  conda-forge
#     pyrsistent-0.17.3          |   py39hcbf5805_2          87 KB  conda-forge
#     pytest-6.2.4               |   py39h6e9494a_0         433 KB  conda-forge
#     pytest-cov-2.11.1          |     pyh44b312d_0          21 KB  conda-forge
#     python-3.9.4               |h9133fd0_0_cpython        12.6 MB  conda-forge
#     python_abi-3.9             |           1_cp39           4 KB  conda-forge
#     pyzmq-22.0.3               |   py39h7fec2f1_1         461 KB  conda-forge
#     readline-8.1               |       h05e3726_0         266 KB  conda-forge
#     sarge-0.1.6                |     pyh44b312d_0          20 KB  conda-forge
#     setuptools-49.6.0          |   py39h6e9494a_3         950 KB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     sqlite-3.35.5              |       h44b9ce1_0         1.7 MB  conda-forge
#     terminado-0.9.4            |   py39h6e9494a_0          26 KB  conda-forge
#     tornado-6.1                |   py39hcbf5805_1         646 KB  conda-forge
#     tzdata-2021a               |       he74cb21_0         121 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        70.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   appnope            conda-forge/osx-64::appnope-0.1.2-py39h6e9494a_1
#   argon2-cffi        conda-forge/osx-64::argon2-cffi-20.1.0-py39hcbf5805_2
#   async_generator    conda-forge/noarch::async_generator-1.10-py_0
#   attrs              conda-forge/noarch::attrs-21.2.0-pyhd8ed1ab_0
#   backcall           conda-forge/noarch::backcall-0.2.0-pyh9f0ad1d_0
#   backports          conda-forge/noarch::backports-1.0-py_2
#   backports.functoo~ conda-forge/noarch::backports.functools_lru_cache-1.6.4-pyhd8ed1ab_0
#   bleach             conda-forge/noarch::bleach-3.3.0-pyh44b312d_0
#   ca-certificates    conda-forge/osx-64::ca-certificates-2020.12.5-h033912b_0
#   certifi            conda-forge/osx-64::certifi-2020.12.5-py39h6e9494a_1
#   cffi               conda-forge/osx-64::cffi-1.14.5-py39h319c39b_0
#   coverage           conda-forge/osx-64::coverage-5.5-py39h89e85a6_0
#   cycler             conda-forge/noarch::cycler-0.10.0-py_2
#   decorator          conda-forge/noarch::decorator-5.0.7-pyhd8ed1ab_0
#   defusedxml         conda-forge/noarch::defusedxml-0.7.1-pyhd8ed1ab_0
#   entrypoints        conda-forge/noarch::entrypoints-0.3-pyhd8ed1ab_1003
#   freetype           conda-forge/osx-64::freetype-2.10.4-h4cff582_1
#   importlib-metadata conda-forge/osx-64::importlib-metadata-4.0.1-py39h6e9494a_0
#   iniconfig          conda-forge/noarch::iniconfig-1.1.1-pyh9f0ad1d_0
#   ipykernel          conda-forge/osx-64::ipykernel-5.5.4-py39h71a6800_0
#   ipython            conda-forge/osx-64::ipython-7.23.1-py39h71a6800_0
#   ipython_genutils   conda-forge/noarch::ipython_genutils-0.2.0-py_1
#   jedi               conda-forge/osx-64::jedi-0.18.0-py39h6e9494a_2
#   jinja2             conda-forge/noarch::jinja2-2.11.3-pyh44b312d_0
#   jpeg               conda-forge/osx-64::jpeg-9d-hbcb3906_0
#   jsonschema         conda-forge/noarch::jsonschema-3.2.0-pyhd8ed1ab_3
#   jupyter_client     conda-forge/noarch::jupyter_client-6.1.12-pyhd8ed1ab_0
#   jupyter_core       conda-forge/osx-64::jupyter_core-4.7.1-py39h6e9494a_0
#   jupyterlab_pygmen~ conda-forge/noarch::jupyterlab_pygments-0.1.2-pyh9f0ad1d_0
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.3.1-py39hedf5dff_1
#   lcms2              conda-forge/osx-64::lcms2-2.12-h577c468_0
#   libblas            conda-forge/osx-64::libblas-3.9.0-9_openblas
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-9_openblas
#   libcxx             conda-forge/osx-64::libcxx-11.1.0-habf9029_0
#   libffi             conda-forge/osx-64::libffi-3.3-h046ec9c_2
#   libgfortran        conda-forge/osx-64::libgfortran-5.0.0-9_3_0_h6c81a4c_22
#   libgfortran5       conda-forge/osx-64::libgfortran5-9.3.0-h6c81a4c_22
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-9_openblas
#   libopenblas        conda-forge/osx-64::libopenblas-0.3.15-openmp_h5e1b9a4_0
#   libpng             conda-forge/osx-64::libpng-1.6.37-h7cec526_2
#   libsodium          conda-forge/osx-64::libsodium-1.0.18-hbcb3906_1
#   libtiff            conda-forge/osx-64::libtiff-4.2.0-h7c11950_1
#   libwebp-base       conda-forge/osx-64::libwebp-base-1.2.0-h0d85af4_2
#   llvm-openmp        conda-forge/osx-64::llvm-openmp-11.1.0-hda6cdc1_1
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.3-h046ec9c_0
#   markupsafe         conda-forge/osx-64::markupsafe-1.1.1-py39hcbf5805_3
#   matplotlib         conda-forge/osx-64::matplotlib-3.4.2-py39h6e9494a_0
#   matplotlib-base    conda-forge/osx-64::matplotlib-base-3.4.2-py39hb07454d_0
#   matplotlib-inline  conda-forge/noarch::matplotlib-inline-0.1.2-pyhd8ed1ab_2
#   mistune            conda-forge/osx-64::mistune-0.8.4-py39hcbf5805_1003
#   more-itertools     conda-forge/noarch::more-itertools-8.7.0-pyhd8ed1ab_1
#   nbclient           conda-forge/noarch::nbclient-0.5.3-pyhd8ed1ab_0
#   nbconvert          conda-forge/osx-64::nbconvert-6.0.7-py39h6e9494a_3
#   nbformat           conda-forge/noarch::nbformat-5.1.3-pyhd8ed1ab_0
#   ncurses            conda-forge/osx-64::ncurses-6.2-h2e338ed_4
#   nest-asyncio       conda-forge/noarch::nest-asyncio-1.5.1-pyhd8ed1ab_0
#   notebook           conda-forge/noarch::notebook-6.3.0-pyha770c72_1
#   numpy              conda-forge/osx-64::numpy-1.20.2-py39h7eed0ac_0
#   olefile            conda-forge/noarch::olefile-0.46-pyh9f0ad1d_1
#   oommf              conda-forge/osx-64::oommf-2.0a1-h7b1db23_1002
#   openjpeg           conda-forge/osx-64::openjpeg-2.4.0-h6cbf5cd_0
#   openssl            conda-forge/osx-64::openssl-1.1.1k-h0d85af4_0
#   packaging          conda-forge/noarch::packaging-20.9-pyh44b312d_0
#   pandoc             conda-forge/osx-64::pandoc-2.13-h0d85af4_0
#   pandocfilters      conda-forge/noarch::pandocfilters-1.4.2-py_1
#   parso              conda-forge/noarch::parso-0.8.2-pyhd8ed1ab_0
#   pexpect            conda-forge/noarch::pexpect-4.8.0-pyh9f0ad1d_2
#   pickleshare        conda-forge/noarch::pickleshare-0.7.5-py_1003
#   pillow             conda-forge/osx-64::pillow-8.1.2-py39h5fdd921_1
#   pip                conda-forge/noarch::pip-21.1.1-pyhd8ed1ab_0
#   pluggy             conda-forge/osx-64::pluggy-0.13.1-py39h6e9494a_4
#   prometheus_client  conda-forge/noarch::prometheus_client-0.10.1-pyhd8ed1ab_0
#   prompt-toolkit     conda-forge/noarch::prompt-toolkit-3.0.18-pyha770c72_0
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0
#   py                 conda-forge/noarch::py-1.10.0-pyhd3deb0d_0
#   pycparser          conda-forge/noarch::pycparser-2.20-pyh9f0ad1d_2
#   pygments           conda-forge/noarch::pygments-2.9.0-pyhd8ed1ab_0
#   pyparsing          conda-forge/noarch::pyparsing-2.4.7-pyh9f0ad1d_0
#   pyrsistent         conda-forge/osx-64::pyrsistent-0.17.3-py39hcbf5805_2
#   pytest             conda-forge/osx-64::pytest-6.2.4-py39h6e9494a_0
#   pytest-cov         conda-forge/noarch::pytest-cov-2.11.1-pyh44b312d_0
#   python             conda-forge/osx-64::python-3.9.4-h9133fd0_0_cpython
#   python-dateutil    conda-forge/noarch::python-dateutil-2.8.1-py_0
#   python_abi         conda-forge/osx-64::python_abi-3.9-1_cp39
#   pyzmq              conda-forge/osx-64::pyzmq-22.0.3-py39h7fec2f1_1
#   readline           conda-forge/osx-64::readline-8.1-h05e3726_0
#   sarge              conda-forge/noarch::sarge-0.1.6-pyh44b312d_0
#   send2trash         conda-forge/noarch::send2trash-1.5.0-py_0
#   setuptools         conda-forge/osx-64::setuptools-49.6.0-py39h6e9494a_3
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   sqlite             conda-forge/osx-64::sqlite-3.35.5-h44b9ce1_0
#   terminado          conda-forge/osx-64::terminado-0.9.4-py39h6e9494a_0
#   testpath           conda-forge/noarch::testpath-0.4.4-py_0
#   tk                 conda-forge/osx-64::tk-8.6.10-h0419947_1
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_0
#   tornado            conda-forge/osx-64::tornado-6.1-py39hcbf5805_1
#   traitlets          conda-forge/noarch::traitlets-5.0.5-py_0
#   tzdata             conda-forge/noarch::tzdata-2021a-he74cb21_0
#   wcwidth            conda-forge/noarch::wcwidth-0.2.5-pyh9f0ad1d_2
#   webencodings       conda-forge/noarch::webencodings-0.5.1-py_1
#   wheel              conda-forge/noarch::wheel-0.36.2-pyhd3deb0d_0
#   xz                 conda-forge/osx-64::xz-5.2.5-haf1e3a3_1
#   zeromq             conda-forge/osx-64::zeromq-4.3.4-h1c7c35f_0
#   zipp               conda-forge/noarch::zipp-3.4.1-pyhd8ed1ab_0
#   zlib               conda-forge/osx-64::zlib-1.2.11-h7795811_1010
#   zstd               conda-forge/osx-64::zstd-1.4.9-h582d3a0_0
#
#
#
# Downloading and Extracting Packages
# setuptools-49.6.0    | 950 KB    | ##################################### | 100%
# decorator-5.0.7      | 11 KB     | ##################################### | 100%
# certifi-2020.12.5    | 143 KB    | ##################################### | 100%
# mistune-0.8.4        | 54 KB     | ##################################### | 100%
# terminado-0.9.4      | 26 KB     | ##################################### | 100%
# parso-0.8.2          | 68 KB     | ##################################### | 100%
# libgfortran-5.0.0    | 19 KB     | ##################################### | 100%
# jedi-0.18.0          | 932 KB    | ##################################### | 100%
# six-1.16.0           | 14 KB     | ##################################### | 100%
# sarge-0.1.6          | 20 KB     | ##################################### | 100%
# more-itertools-8.7.0 | 39 KB     | ##################################### | 100%
# importlib-metadata-4 | 30 KB     | ##################################### | 100%
# pyzmq-22.0.3         | 461 KB    | ##################################### | 100%
# pip-21.1.1           | 1.1 MB    | ##################################### | 100%
# libtiff-4.2.0        | 623 KB    | ##################################### | 100%
# llvm-openmp-11.1.0   | 268 KB    | ##################################### | 100%
# matplotlib-inline-0. | 11 KB     | ##################################### | 100%
# nbformat-5.1.3       | 47 KB     | ##################################### | 100%
# libblas-3.9.0        | 11 KB     | ##################################### | 100%
# libwebp-base-1.2.0   | 700 KB    | ##################################### | 100%
# liblapack-3.9.0      | 11 KB     | ##################################### | 100%
# pandoc-2.13          | 13.2 MB   | ##################################### | 100%
# ipykernel-5.5.4      | 167 KB    | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# prompt-toolkit-3.0.1 | 244 KB    | ##################################### | 100%
# nest-asyncio-1.5.1   | 9 KB      | ##################################### | 100%
# pillow-8.1.2         | 653 KB    | ##################################### | 100%
# ipython-7.23.1       | 1.1 MB    | ##################################### | 100%
# cffi-1.14.5          | 219 KB    | ##################################### | 100%
# openssl-1.1.1k       | 1.9 MB    | ##################################### | 100%
# matplotlib-3.4.2     | 7 KB      | ##################################### | 100%
# attrs-21.2.0         | 44 KB     | ##################################### | 100%
# coverage-5.5         | 257 KB    | ##################################### | 100%
# nbconvert-6.0.7      | 530 KB    | ##################################### | 100%
# matplotlib-base-3.4. | 7.2 MB    | ##################################### | 100%
# readline-8.1         | 266 KB    | ##################################### | 100%
# sqlite-3.35.5        | 1.7 MB    | ##################################### | 100%
# tzdata-2021a         | 121 KB    | ##################################### | 100%
# python_abi-3.9       | 4 KB      | ##################################### | 100%
# jupyter_core-4.7.1   | 72 KB     | ##################################### | 100%
# kiwisolver-1.3.1     | 59 KB     | ##################################### | 100%
# python-3.9.4         | 12.6 MB   | ##################################### | 100%
# libgfortran5-9.3.0   | 1.7 MB    | ##################################### | 100%
# numpy-1.20.2         | 5.4 MB    | ##################################### | 100%
# tornado-6.1          | 646 KB    | ##################################### | 100%
# prometheus_client-0. | 46 KB     | ##################################### | 100%
# pytest-6.2.4         | 433 KB    | ##################################### | 100%
# libffi-3.3           | 45 KB     | ##################################### | 100%
# markupsafe-1.1.1     | 25 KB     | ##################################### | 100%
# notebook-6.3.0       | 6.1 MB    | ##################################### | 100%
# pygments-2.9.0       | 754 KB    | ##################################### | 100%
# backports.functools_ | 9 KB      | ##################################### | 100%
# libopenblas-0.3.15   | 8.7 MB    | ##################################### | 100%
# pyrsistent-0.17.3    | 87 KB     | ##################################### | 100%
# openjpeg-2.4.0       | 446 KB    | ##################################### | 100%
# appnope-0.1.2        | 10 KB     | ##################################### | 100%
# pluggy-0.13.1        | 29 KB     | ##################################### | 100%
# argon2-cffi-20.1.0   | 45 KB     | ##################################### | 100%
# pytest-cov-2.11.1    | 21 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate ubermag-dev
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda env list
# Out:
# # conda environments:
# #
# cv37                     /Users/fangohr/.conda/envs/cv37
# cv38                     /Users/fangohr/.conda/envs/cv38
#                          /Users/fangohr/.pyenv/versions/anaconda3-2020.07
# base                  *  /Users/fangohr/.pyenv/versions/anaconda3-2020.11
# ubermag-dev              /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev
# ubermag-environment      /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-environment
#                          /Users/fangohr/anaconda3
#                          /Users/fangohr/anaconda3/envs/da-docs
#                          /Users/fangohr/anaconda3/envs/jupyterbook
#                          /Users/fangohr/anaconda3/envs/karabo
#                          /Users/fangohr/anaconda3/envs/oscovida
#                          /Users/fangohr/anaconda3/envs/oscovida2
#                          /Users/fangohr/anaconda3/envs/python2
#                          /Users/fangohr/anaconda3/envs/python=3.7
#                          /Users/fangohr/anaconda3/envs/repo2docker
#                          /Users/fangohr/anaconda3/envs/ubermag-environment
#                          /Users/fangohr/opt/anaconda3

# %%
# !conda activate ubermag-dev && conda env list
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %% [markdown]
# The command above seems to fail because I use `pyenv` to create the anaconda environment. (This is an open question.)
#
# We can activate the conda environment using the following command (on this installation on OSX):

# %%
# !source /Users/fangohr/.pyenv/versions/anaconda3-2020.11/bin/activate ubermag-dev && conda env list
# Out:
# # conda environments:
# #
# cv37                     /Users/fangohr/.conda/envs/cv37
# cv38                     /Users/fangohr/.conda/envs/cv38
#                          /Users/fangohr/.pyenv/versions/anaconda3-2020.07
# base                     /Users/fangohr/.pyenv/versions/anaconda3-2020.11
# ubermag-dev           *  /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev
# ubermag-environment      /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-environment
#                          /Users/fangohr/anaconda3
#                          /Users/fangohr/anaconda3/envs/da-docs
#                          /Users/fangohr/anaconda3/envs/jupyterbook
#                          /Users/fangohr/anaconda3/envs/karabo
#                          /Users/fangohr/anaconda3/envs/oscovida
#                          /Users/fangohr/anaconda3/envs/oscovida2
#                          /Users/fangohr/anaconda3/envs/python2
#                          /Users/fangohr/anaconda3/envs/python=3.7
#                          /Users/fangohr/anaconda3/envs/repo2docker
#                          /Users/fangohr/anaconda3/envs/ubermag-environment
#                          /Users/fangohr/opt/anaconda3

# %% [markdown]
# Put this into a command variable to avoid lots of typing:

# %%
cmd = 'source /Users/fangohr/.pyenv/versions/anaconda3-2020.11/bin/activate ubermag-dev'

# %% [markdown]
# If Conda is working directly, one shoudl be able to use
#
# `cmd = 'conda activate ubermag-dev'`

# %%
# !$cmd && conda env list
# Out:
# # conda environments:
# #
# cv37                     /Users/fangohr/.conda/envs/cv37
# cv38                     /Users/fangohr/.conda/envs/cv38
#                          /Users/fangohr/.pyenv/versions/anaconda3-2020.07
# base                     /Users/fangohr/.pyenv/versions/anaconda3-2020.11
# ubermag-dev           *  /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev
# ubermag-environment      /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-environment
#                          /Users/fangohr/anaconda3
#                          /Users/fangohr/anaconda3/envs/da-docs
#                          /Users/fangohr/anaconda3/envs/jupyterbook
#                          /Users/fangohr/anaconda3/envs/karabo
#                          /Users/fangohr/anaconda3/envs/oscovida
#                          /Users/fangohr/anaconda3/envs/oscovida2
#                          /Users/fangohr/anaconda3/envs/python2
#                          /Users/fangohr/anaconda3/envs/python=3.7
#                          /Users/fangohr/anaconda3/envs/repo2docker
#                          /Users/fangohr/anaconda3/envs/ubermag-environment
#                          /Users/fangohr/opt/anaconda3

# %% [markdown]
# ## Create subdirectory and clone all repos into that

# %%
# !mkdir repos

# %%
cd repos
# Out:
# /Users/fangohr/git/ubermag-devtools/repos

# %%
# !$cmd && sh ../clone-and-install-repos.sh
# Out:
# fatal: destination path 'ubermagutil' already exists and is not an empty directory.
# fatal: destination path 'discretisedfield' already exists and is not an empty directory.
# fatal: destination path 'ubermagtable' already exists and is not an empty directory.
# fatal: destination path 'micromagneticmodel' already exists and is not an empty directory.
# fatal: destination path 'micromagneticdata' already exists and is not an empty directory.
# fatal: destination path 'micromagnetictests' already exists and is not an empty directory.
# fatal: destination path 'oommfc' already exists and is not an empty directory.
# fatal: destination path 'ubermag' already exists and is not an empty directory.
# ~/git/ubermag-devtools/repos/ubermagutil ~/git/ubermag-devtools/repos
# Obtaining file:///Users/fangohr/git/ubermag-devtools/repos/ubermagutil
# Requirement already satisfied: numpy>=1.19 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagutil==0.4.1) (1.20.2)
# Requirement already satisfied: pytest>=6.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagutil==0.4.1) (6.2.4)
# Requirement already satisfied: attrs>=19.2.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1) (21.2.0)
# Requirement already satisfied: iniconfig in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1) (1.1.1)
# Requirement already satisfied: packaging in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1) (1.10.0)
# Requirement already satisfied: toml in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1) (0.10.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from packaging->pytest>=6.2->ubermagutil==0.4.1) (2.4.7)
# Installing collected packages: ubermagutil
#   Running setup.py develop for ubermagutil
# Successfully installed ubermagutil-0.4.1
# ~/git/ubermag-devtools/repos
# ~/git/ubermag-devtools/repos/discretisedfield ~/git/ubermag-devtools/repos
# Obtaining file:///Users/fangohr/git/ubermag-devtools/repos/discretisedfield
# Requirement already satisfied: ubermagutil==0.4.1 in /Users/fangohr/git/ubermag-devtools/repos/ubermagutil (from discretisedfield==0.11.1) (0.4.1)
# Requirement already satisfied: pandas>=1.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1) (1.2.4)
# Requirement already satisfied: matplotlib>=3.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1) (3.4.2)
# Requirement already satisfied: jupyterlab==2.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1) (2.2.0)
# Requirement already satisfied: h5py>=3.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1) (3.2.1)
# Requirement already satisfied: k3d>=2.9 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1) (2.9.4)
# Requirement already satisfied: scipy>=1.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1) (1.6.3)
# Requirement already satisfied: notebook>=4.3.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->discretisedfield==0.11.1) (6.3.0)
# Requirement already satisfied: jupyterlab-server<2.0,>=1.1.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->discretisedfield==0.11.1) (1.2.0)
# Requirement already satisfied: tornado!=6.0.0,!=6.0.1,!=6.0.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->discretisedfield==0.11.1) (6.1)
# Requirement already satisfied: jinja2>=2.10 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->discretisedfield==0.11.1) (2.11.3)
# Requirement already satisfied: numpy>=1.19 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagutil==0.4.1->discretisedfield==0.11.1) (1.20.2)
# Requirement already satisfied: pytest>=6.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagutil==0.4.1->discretisedfield==0.11.1) (6.2.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jinja2>=2.10->jupyterlab==2.2->discretisedfield==0.11.1) (1.1.1)
# Requirement already satisfied: json5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (0.9.5)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (3.2.0)
# Requirement already satisfied: requests in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (2.25.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (21.2.0)
# Requirement already satisfied: setuptools in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (49.6.0.post20210108)
# Requirement already satisfied: six>=1.11.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (0.17.3)
# Requirement already satisfied: ipydatawidgets in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1) (4.2.0)
# Requirement already satisfied: ipywidgets>=7.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1) (7.6.3)
# Requirement already satisfied: traitlets in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1) (5.0.5)
# Requirement already satisfied: traittypes in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1) (0.2.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (5.5.4)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (5.1.3)
# Requirement already satisfied: ipython>=4.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (7.23.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (1.0.0)
# Requirement already satisfied: jupyter-client in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (6.1.12)
# Requirement already satisfied: appnope in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (4.8.0)
# Requirement already satisfied: backcall in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.2.0)
# Requirement already satisfied: pygments in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (2.9.0)
# Requirement already satisfied: decorator in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (5.0.7)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (3.0.18)
# Requirement already satisfied: matplotlib-inline in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.18.0)
# Requirement already satisfied: pickleshare in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1) (8.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1) (2.8.1)
# Requirement already satisfied: jupyter-core in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (4.7.1)
# Requirement already satisfied: ipython-genutils in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.2.0)
# Requirement already satisfied: prometheus-client in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.10.1)
# Requirement already satisfied: pyzmq>=17 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (22.0.3)
# Requirement already satisfied: nbconvert in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.9.4)
# Requirement already satisfied: argon2-cffi in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (1.5.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pandas>=1.1->discretisedfield==0.11.1) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1) (0.2.5)
# Requirement already satisfied: iniconfig in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1) (1.1.1)
# Requirement already satisfied: packaging in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1) (1.10.0)
# Requirement already satisfied: toml in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1) (0.10.2)
# Requirement already satisfied: cffi>=1.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (1.14.5)
# Requirement already satisfied: pycparser in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (2.20)
# Requirement already satisfied: defusedxml in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.1.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.8.4)
# Requirement already satisfied: bleach in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (3.3.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (1.4.2)
# Requirement already satisfied: testpath in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.4.4)
# Requirement already satisfied: async-generator in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (1.5.1)
# Requirement already satisfied: webencodings in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1) (0.5.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1) (4.0.0)
# Installing collected packages: discretisedfield
#   Running setup.py develop for discretisedfield
# Successfully installed discretisedfield-0.11.1
# ~/git/ubermag-devtools/repos
# ~/git/ubermag-devtools/repos/ubermagtable ~/git/ubermag-devtools/repos
# Obtaining file:///Users/fangohr/git/ubermag-devtools/repos/ubermagtable
# Requirement already satisfied: ubermagutil==0.4.1 in /Users/fangohr/git/ubermag-devtools/repos/ubermagutil (from ubermagtable==0.6.1) (0.4.1)
# Requirement already satisfied: pandas>=1.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagtable==0.6.1) (1.2.4)
# Requirement already satisfied: matplotlib>=3.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagtable==0.6.1) (3.4.2)
# Requirement already satisfied: jupyterlab==2.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagtable==0.6.1) (2.2.0)
# Requirement already satisfied: ipywidgets>=7.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagtable==0.6.1) (7.6.3)
# Requirement already satisfied: jupyterlab-server<2.0,>=1.1.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->ubermagtable==0.6.1) (1.2.0)
# Requirement already satisfied: jinja2>=2.10 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->ubermagtable==0.6.1) (2.11.3)
# Requirement already satisfied: tornado!=6.0.0,!=6.0.1,!=6.0.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->ubermagtable==0.6.1) (6.1)
# Requirement already satisfied: notebook>=4.3.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->ubermagtable==0.6.1) (6.3.0)
# Requirement already satisfied: numpy>=1.19 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagutil==0.4.1->ubermagtable==0.6.1) (1.20.2)
# Requirement already satisfied: pytest>=6.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagutil==0.4.1->ubermagtable==0.6.1) (6.2.4)
# Requirement already satisfied: ipython>=4.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.5->ubermagtable==0.6.1) (7.23.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.5->ubermagtable==0.6.1) (5.1.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.5->ubermagtable==0.6.1) (1.0.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.5->ubermagtable==0.6.1) (5.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.5->ubermagtable==0.6.1) (5.5.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.5->ubermagtable==0.6.1) (3.5.1)
# Requirement already satisfied: jupyter-client in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->ubermagtable==0.6.1) (6.1.12)
# Requirement already satisfied: appnope in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->ubermagtable==0.6.1) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (0.18.0)
# Requirement already satisfied: pickleshare in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (0.1.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (3.0.18)
# Requirement already satisfied: pygments in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (2.9.0)
# Requirement already satisfied: decorator in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (5.0.7)
# Requirement already satisfied: setuptools>=18.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (49.6.0.post20210108)
# Requirement already satisfied: pexpect>4.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (4.8.0)
# Requirement already satisfied: backcall in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jinja2>=2.10->jupyterlab==2.2->ubermagtable==0.6.1) (1.1.1)
# Requirement already satisfied: json5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (0.9.5)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (3.2.0)
# Requirement already satisfied: requests in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (2.25.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (0.17.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->ubermagtable==0.6.1) (8.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->ubermagtable==0.6.1) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->ubermagtable==0.6.1) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->ubermagtable==0.6.1) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->ubermagtable==0.6.1) (2.8.1)
# Requirement already satisfied: jupyter-core in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5->ubermagtable==0.6.1) (4.7.1)
# Requirement already satisfied: ipython-genutils in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5->ubermagtable==0.6.1) (0.2.0)
# Requirement already satisfied: argon2-cffi in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.9.4)
# Requirement already satisfied: prometheus-client in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.10.1)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (1.5.0)
# Requirement already satisfied: nbconvert in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (22.0.3)
# Requirement already satisfied: pytz>=2017.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pandas>=1.1->ubermagtable==0.6.1) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1) (0.2.5)
# Requirement already satisfied: iniconfig in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->ubermagtable==0.6.1) (1.1.1)
# Requirement already satisfied: packaging in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->ubermagtable==0.6.1) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->ubermagtable==0.6.1) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->ubermagtable==0.6.1) (1.10.0)
# Requirement already satisfied: toml in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->ubermagtable==0.6.1) (0.10.2)
# Requirement already satisfied: cffi>=1.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (1.14.5)
# Requirement already satisfied: pycparser in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (2.20)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.5.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (1.4.2)
# Requirement already satisfied: defusedxml in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.7.1)
# Requirement already satisfied: testpath in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.1.2)
# Requirement already satisfied: bleach in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (3.3.0)
# Requirement already satisfied: nest-asyncio in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (1.5.1)
# Requirement already satisfied: async-generator in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (1.10)
# Requirement already satisfied: webencodings in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.3.1->jupyterlab==2.2->ubermagtable==0.6.1) (0.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->ubermagtable==0.6.1) (4.0.0)
# Installing collected packages: ubermagtable
#   Running setup.py develop for ubermagtable
# Successfully installed ubermagtable-0.6.1
# ~/git/ubermag-devtools/repos
# ~/git/ubermag-devtools/repos/micromagneticmodel ~/git/ubermag-devtools/repos
# Obtaining file:///Users/fangohr/git/ubermag-devtools/repos/micromagneticmodel
# Requirement already satisfied: discretisedfield==0.11.1 in /Users/fangohr/git/ubermag-devtools/repos/discretisedfield (from micromagneticmodel==0.11.1) (0.11.1)
# Requirement already satisfied: ubermagutil==0.4.1 in /Users/fangohr/git/ubermag-devtools/repos/ubermagutil (from discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.4.1)
# Requirement already satisfied: pandas>=1.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1->micromagneticmodel==0.11.1) (1.2.4)
# Requirement already satisfied: matplotlib>=3.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1->micromagneticmodel==0.11.1) (3.4.2)
# Requirement already satisfied: jupyterlab==2.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1->micromagneticmodel==0.11.1) (2.2.0)
# Requirement already satisfied: h5py>=3.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1->micromagneticmodel==0.11.1) (3.2.1)
# Requirement already satisfied: k3d>=2.9 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1->micromagneticmodel==0.11.1) (2.9.4)
# Requirement already satisfied: scipy>=1.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from discretisedfield==0.11.1->micromagneticmodel==0.11.1) (1.6.3)
# Requirement already satisfied: notebook>=4.3.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (6.3.0)
# Requirement already satisfied: jinja2>=2.10 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (2.11.3)
# Requirement already satisfied: jupyterlab-server<2.0,>=1.1.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (1.2.0)
# Requirement already satisfied: tornado!=6.0.0,!=6.0.1,!=6.0.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (6.1)
# Requirement already satisfied: numpy>=1.19 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagutil==0.4.1->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (1.20.2)
# Requirement already satisfied: pytest>=6.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ubermagutil==0.4.1->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (6.2.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jinja2>=2.10->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (1.1.1)
# Requirement already satisfied: json5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.9.5)
# Requirement already satisfied: requests in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (2.25.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (21.2.0)
# Requirement already satisfied: setuptools in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (49.6.0.post20210108)
# Requirement already satisfied: six>=1.11.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (1.16.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.17.3)
# Requirement already satisfied: ipydatawidgets in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (4.2.0)
# Requirement already satisfied: traitlets in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (5.0.5)
# Requirement already satisfied: ipywidgets>=7.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (7.6.3)
# Requirement already satisfied: traittypes in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.2.1)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (5.5.4)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (7.23.1)
# Requirement already satisfied: appnope in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.1.2)
# Requirement already satisfied: jupyter-client in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (6.1.12)
# Requirement already satisfied: pexpect>4.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (4.8.0)
# Requirement already satisfied: pygments in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (2.9.0)
# Requirement already satisfied: jedi>=0.16 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.18.0)
# Requirement already satisfied: pickleshare in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.1.2)
# Requirement already satisfied: decorator in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (5.0.7)
# Requirement already satisfied: backcall in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (3.0.18)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (8.1.2)
# Requirement already satisfied: cycler>=0.10 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (2.4.7)
# Requirement already satisfied: jupyter-core in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.1->k3d>=2.9->discretisedfield==0.11.1->micromagneticmodel==0.11.1) (4.7.1)
# ...
# Requirement already satisfied: jupyter-client in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (6.1.12)
# Requirement already satisfied: pexpect>4.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (3.0.18)
# Requirement already satisfied: jedi>=0.16 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (0.18.0)
# Requirement already satisfied: pickleshare in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (0.7.5)
# Requirement already satisfied: backcall in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (0.2.0)
# Requirement already satisfied: pygments in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (2.9.0)
# Requirement already satisfied: decorator in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (5.0.7)
# Requirement already satisfied: matplotlib-inline in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (49.6.0.post20210108)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (0.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jinja2>=2.10->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.1.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (3.2.0)
# Requirement already satisfied: json5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.9.5)
# Requirement already satisfied: requests in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (2.25.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (21.2.0)
# Requirement already satisfied: six>=1.11.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from jsonschema>=3.0.1->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.16.0)
# Requirement already satisfied: ipydatawidgets in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (4.2.0)
# Requirement already satisfied: traittypes in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from k3d>=2.9->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.2.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (8.1.2)
# Requirement already satisfied: cycler>=0.10 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from matplotlib>=3.3->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.3.1)
# Requirement already satisfied: jupyter-core in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (4.7.1)
# Requirement already satisfied: ipython-genutils in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (0.2.0)
# Requirement already satisfied: nbconvert in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (22.0.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.5.0)
# Requirement already satisfied: argon2-cffi in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (20.1.0)
# Requirement already satisfied: prometheus-client in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.10.1)
# Requirement already satisfied: terminado>=0.8.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.9.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pandas>=1.1->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5->ubermagtable==0.6.1->micromagneticdata==0.5.1->ubermag==0.51) (0.2.5)
# Requirement already satisfied: iniconfig in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.1.1)
# Requirement already satisfied: packaging in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.10.0)
# Requirement already satisfied: toml in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from pytest>=6.2->ubermagutil==0.4.1->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.10.2)
# Requirement already satisfied: cffi>=1.0.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.14.5)
# Requirement already satisfied: pycparser in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (2.20)
# Requirement already satisfied: testpath in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.5.3)
# Requirement already satisfied: bleach in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (3.3.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.8.4)
# Requirement already satisfied: defusedxml in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.7.1)
# Requirement already satisfied: async-generator in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.5.1)
# Requirement already satisfied: webencodings in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.3.1->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (0.5.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages (from requests->jupyterlab-server<2.0,>=1.1.5->jupyterlab==2.2->discretisedfield==0.11.1->micromagneticdata==0.5.1->ubermag==0.51) (2.10)
# Installing collected packages: ubermag
#   Attempting uninstall: ubermag
#     Found existing installation: ubermag 0.51
#     Uninstalling ubermag-0.51:
#       Successfully uninstalled ubermag-0.51
#   Running setup.py develop for ubermag
# Successfully installed ubermag-0.51
# ~/git/ubermag-devtools/repos
# Found existing installation: ubermagutil 0.4.1
# Uninstalling ubermagutil-0.4.1:
#   Would remove:
#     /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages/ubermagutil.egg-link
# Proceed (y/n)? ^C
# ERROR: Operation cancelled by user
# ../clone-and-install-repos.sh: line 58: c: command not found

# %%
# !$cmd && python -c "import ubermag"

# %% [markdown]
# Ideally, we would run `ubermag.test()` here to check all works.

# %% [markdown]
# Shorter test:

# %%
# !$cmd && python -c "import discretisedfield as d; d.test()"
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.9.4, pytest-6.2.4, py-1.10.0, pluggy-0.13.1 -- /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/fangohr/git/ubermag-devtools/repos/discretisedfield
# plugins: cov-2.11.1
# collected 139 items
#
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_init_valid_args PASSED [  0%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_init_invalid_args PASSED [  1%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_set_with_ndarray PASSED [  2%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_set_with_callable PASSED [  2%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_set_with_dict PASSED [  3%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_set_exception PASSED [  4%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_value PASSED [  5%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_norm PASSED [  5%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_norm_is_not_preserved PASSED [  6%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_norm_zero_field_exception PASSED [  7%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_zero PASSED [  7%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_orientation PASSED [  8%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_average PASSED [  9%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_field_component PASSED [ 10%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_get_attribute_exception PASSED [ 10%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_dir PASSED [ 11%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_eq PASSED [ 12%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_allclose PASSED [ 12%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_point_neg PASSED [ 13%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_pow PASSED [ 14%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_add_subtract PASSED [ 15%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_mul_truediv PASSED [ 15%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_dot PASSED [ 16%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_cross PASSED [ 17%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_lshift PASSED [ 17%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_all_operators PASSED [ 18%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_pad PASSED [ 19%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_derivative PASSED [ 20%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_derivative_pbc PASSED [ 20%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_derivative_neumann PASSED [ 21%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_derivative_single_cell PASSED [ 22%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_grad PASSED [ 23%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_div_curl PASSED [ 23%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_laplace PASSED [ 24%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_integral PASSED [ 25%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_line PASSED [ 25%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_plane PASSED [ 26%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_getitem PASSED [ 27%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_project PASSED [ 28%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_angle PASSED [ 28%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_write_read_ovf PASSED [ 29%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_write_read_vtk PASSED [ 30%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_write_read_hdf5 PASSED [ 30%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_read_write_invalid_extension PASSED [ 31%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_mpl_scalar PASSED [ 32%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_mpl_vector PASSED [ 33%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_mpl PASSED [ 33%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_k3d_nonzero PASSED [ 34%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_k3d_scalar PASSED [ 35%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_k3d_vector PASSED [ 35%]
# discretisedfield/discretisedfield/tests/test_field.py::TestField::test_plot_large_sample PASSED [ 36%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_init_valid_args PASSED [ 37%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_init_invalid_args PASSED [ 38%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_init_subregions PASSED [ 38%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_init_with_region_and_points PASSED [ 39%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_init_with_n_and_cell PASSED [ 40%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_region_not_aggregate_of_cell PASSED [ 41%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_cell_greater_than_domain PASSED [ 41%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_len PASSED [ 42%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_indices_coordinates_iter PASSED [ 43%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_eq PASSED [ 43%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_repr PASSED [ 44%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_index2point PASSED [ 45%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_point2index PASSED [ 46%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_index2point_point2index_mutually_inverse PASSED [ 46%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_axis_points PASSED [ 47%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_neighbours PASSED [ 48%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_line PASSED [ 48%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_plane PASSED [ 49%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_or PASSED [ 50%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_getitem PASSED [ 51%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_pad PASSED [ 51%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_getattr PASSED [ 52%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_dir PASSED [ 53%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_dV PASSED [ 53%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_dS PASSED [ 54%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_mpl PASSED [ 55%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_k3d PASSED [ 56%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_k3d_mpl_subregions PASSED [ 56%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_slider PASSED [ 57%]
# discretisedfield/discretisedfield/tests/test_field.py::TestMesh::test_axis_selector PASSED [ 58%]
# discretisedfield/discretisedfield/tests/test_init.py::test_version PASSED [ 58%]
# discretisedfield/discretisedfield/tests/test_interact.py::test_interact PASSED [ 59%]
# discretisedfield/discretisedfield/tests/test_line.py::TestLine::test_init PASSED [ 60%]
# discretisedfield/discretisedfield/tests/test_line.py::TestLine::test_point_value_columns PASSED [ 61%]
# discretisedfield/discretisedfield/tests/test_line.py::TestLine::test_mpl PASSED [ 61%]
# discretisedfield/discretisedfield/tests/test_line.py::TestLine::test_slider_selector PASSED [ 62%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_init_valid_args PASSED [ 63%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_init_invalid_args PASSED [ 64%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_init_subregions PASSED [ 64%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_init_with_region_and_points PASSED [ 65%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_init_with_n_and_cell PASSED [ 66%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_region_not_aggregate_of_cell PASSED [ 66%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_cell_greater_than_domain PASSED [ 67%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_len PASSED [ 68%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_indices_coordinates_iter PASSED [ 69%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_eq PASSED [ 69%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_repr PASSED [ 70%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_index2point PASSED [ 71%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_point2index PASSED [ 71%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_index2point_point2index_mutually_inverse PASSED [ 72%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_axis_points PASSED [ 73%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_neighbours PASSED [ 74%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_line PASSED [ 74%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_plane PASSED [ 75%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_or PASSED [ 76%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_getitem PASSED [ 76%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_pad PASSED [ 77%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_getattr PASSED [ 78%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_dir PASSED [ 79%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_dV PASSED [ 79%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_dS PASSED [ 80%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_mpl PASSED [ 81%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_k3d PASSED [ 82%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_k3d_mpl_subregions PASSED [ 82%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_slider PASSED [ 83%]
# discretisedfield/discretisedfield/tests/test_mesh.py::TestMesh::test_axis_selector PASSED [ 84%]
# discretisedfield/discretisedfield/tests/test_operators.py::test_instances PASSED [ 84%]
# discretisedfield/discretisedfield/tests/test_operators.py::test_integral PASSED [ 85%]
# discretisedfield/discretisedfield/tests/test_ovf2vtk.py::test_ovf2vtk PASSED [ 86%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_init_valid_args PASSED [ 87%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_init_invalid_args PASSED [ 87%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_init_zero_edge_length PASSED [ 88%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_pmin_pmax_edges_centre_volume PASSED [ 89%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_repr PASSED [ 89%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_eq PASSED [ 90%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_contains PASSED [ 91%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_or PASSED [ 92%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_mpl PASSED [ 92%]
# discretisedfield/discretisedfield/tests/test_region.py::TestRegion::test_k3d PASSED [ 93%]
# discretisedfield/discretisedfield/tests/test_tools.py::test_topological_charge PASSED [ 94%]
# discretisedfield/discretisedfield/tests/test_tools.py::test_emergent_magnetic_field PASSED [ 94%]
# discretisedfield/discretisedfield/tests/test_tools.py::test_neigbouring_cell_angle PASSED [ 95%]
# discretisedfield/discretisedfield/tests/test_tools.py::test_max_neigbouring_cell_angle PASSED [ 96%]
# discretisedfield/discretisedfield/tests/test_tools.py::test_count_lange_cell_angle_regions PASSED [ 97%]
# discretisedfield/discretisedfield/tests/test_tools.py::test_count_bps PASSED [ 97%]
# discretisedfield/discretisedfield/tests/test_util.py::test_array2tuple PASSED [ 98%]
# discretisedfield/discretisedfield/tests/test_util.py::test_bergluescher_angle PASSED [ 99%]
# discretisedfield/discretisedfield/tests/test_util.py::test_assemble_index PASSED [100%]
#
# =============================== warnings summary ===============================
# discretisedfield/tests/test_field.py: 28 warnings
#   /Users/fangohr/.pyenv/versions/anaconda3-2020.11/envs/ubermag-dev/lib/python3.9/site-packages/traitlets/traitlets.py:586: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#     silent = bool(old_value == new_value)
#
# -- Docs: https://docs.pytest.org/en/stable/warnings.html
# ====================== 139 passed, 28 warnings in 32.25s =======================

# %% [markdown]
# Comprehensive test

# %%
# !source activate ubermag-dev && python -c "import ubermag; ubermag.test()"
